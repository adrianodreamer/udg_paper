# %% [markdown]
# # Scraper para Letra Fria

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import random
from urllib.parse import urljoin
from datetime import datetime

# Configuración
BASE_URL = "https://letrafria.com/"
CATEGORY_URL = "https://letrafria.com/category/region/"
OUTPUT_FILE = f"letra_fria_200_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
DELAY = random.uniform(2, 4)
MAX_PAGES = 200  # Para prueba

# Headers optimizados
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'es-MX,es;q=0.9'
}

def get_soup(url):
    """Obtiene el HTML con manejo robusto de errores"""
    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        return BeautifulSoup(response.text, 'html.parser')
    except Exception as e:
        print(f"Error al obtener {url}: {str(e)}")
        return None

def clean_text(text):
    """Limpia el texto preservando estructura"""
    if not text:
        return ""
    return ' '.join(text.strip().split())

def extract_article_data(article_url):
    """Extrae datos de artículo con selectores específicos para Letra Fría"""
    print(f"\nExtrayendo: {article_url}")
    soup = get_soup(article_url)
    if not soup:
        return None
    
    try:
        # 1. Extraer título - selector actualizado
        title = clean_text(soup.find('h1', class_='post-title').get_text())
        
        # 2. Extraer fecha - selectores mejorados
        date_elem = (soup.find('time', class_='post-published') or 
                    soup.find('span', class_='post-date') or
                    soup.find('meta', property='article:published_time'))
        
        date = ""
        if date_elem:
            if date_elem.has_attr('datetime'):
                date = date_elem['datetime'].split('T')[0]  # Formato YYYY-MM-DD
            else:
                date = clean_text(date_elem.get_text())
        
        # 3. Extraer autor - selector específico
        author_elem = soup.find('span', class_='post-author-name') or soup.find('a', rel='author')
        author = clean_text(author_elem.get_text()) if author_elem else ""
        
        # 4. Extraer contenido - enfoque mejorado
        content_div = soup.find('div', class_='post-content') or soup.find('div', class_='entry-content')
        paragraphs = []
        
        if content_div:
            # Eliminar elementos específicos de Letra Fría
            unwanted = ['sharedaddy', 'code-block', 'twitter-tweet', 'wp-block-embed', 
                       'post-tags', 'author-box', 'related-posts']
            for element in content_div.find_all(['script', 'style', 'iframe'] + unwanted):
                element.decompose()
            
            for p in content_div.find_all(['p', 'h2', 'h3']):
                text = clean_text(p.get_text())
                if text and len(text.split()) > 2:
                    paragraphs.append(text)
        
        content = '\n\n'.join(paragraphs) if paragraphs else "Contenido no disponible"
        
        print(f"✓ Título: {title}")
        print(f"✓ Fecha: {date}")
        print(f"✓ Autor: {author}")
        print(f"✓ Caracteres: {len(content)}")
        
        return {
            'titulo': title,
            'articulo': content,
            'fecha': date,
            'autor': author,
            'url': article_url,
            'categoria': 'Región'
        }
        
    except Exception as e:
        print(f"Error procesando artículo: {str(e)}")
        return None

def get_article_links(page_url):
    """Obtiene enlaces con selectores robustos para Letra Fría"""
    print(f"\nObteniendo artículos de: {page_url}")
    soup = get_soup(page_url)
    if not soup:
        return []
    
    links = []
    # Selector principal basado en estructura actual
    articles = soup.select('article.item-post, div.post-item, article.post')
    
    for article in articles:
        if a := article.find('a', href=True, class_=lambda x: x != 'more-link'):
            link = urljoin(BASE_URL, a['href'])
            if link not in links:
                links.append(link)
    
    print(f"Encontrados {len(links)} artículos")
    return links

def main():
    """Función principal con paginación mejorada"""
    with open(OUTPUT_FILE, mode='w', encoding='utf-8', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=['titulo', 'articulo', 'fecha', 'autor', 'url', 'categoria'])
        writer.writeheader()
        
        page_num = 1
        articles_scraped = 0
        
        while page_num <= MAX_PAGES:
            page_url = CATEGORY_URL if page_num == 1 else f"{CATEGORY_URL}page/{page_num}/"
            
            article_links = get_article_links(page_url)
            
            if not article_links:
                print("No se encontraron artículos. Verificando...")
                # Verificación adicional
                soup = get_soup(page_url)
                if soup and soup.find('div', class_='no-results'):
                    print("Confirmado: no hay más artículos.")
                    break
                time.sleep(5)
                continue
            
            for link in article_links:
                article_data = extract_article_data(link)
                if article_data:
                    writer.writerow(article_data)
                    csvfile.flush()
                    articles_scraped += 1
                
                time.sleep(DELAY)
            
            page_num += 1
            time.sleep(DELAY * 1.5)
        
        print(f"\nPrueba completada. Artículos extraídos: {articles_scraped}")
        print(f"Archivo guardado: {OUTPUT_FILE}")

if __name__ == "__main__":
    print("""
    ====================================
    SCRAPER LETRA FRÍA - VERSIÓN FINAL
    Extracción completa garantizada
    ====================================
    """)
    
    start_time = time.time()
    main()
    duration = time.time() - start_time
    print(f"\nTiempo total: {duration//60:.0f}m {duration%60:.0f}s")
# Out:
#     ====================================
#     SCRAPER LETRA FRÍA - VERSIÓN FINAL
#     Extracción completa garantizada
#     ====================================
#
#
# Obteniendo artículos de: https://letrafria.com/category/region/
# Encontrados 5 artículos
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/tras-protestas-acuerdan-mesas-de-trabajo-por-estudiantes-desaparecidos/
# ✓ Título: Tras protestas, acuerdan mesas de trabajo por estudiantes desaparecidos
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2700
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/2/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/arrancaran-obra-de-centro-acuatico-regional-el-grullo-despues-de-16-anos/
# ✓ Título: Arrancarán obra de Centro Acuático Regional El Grullo después de 16 años
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1656
#
# Extrayendo: https://letrafria.com/onu-investigara-a-mexico-por-desapariciones/
# ✓ Título: ONU investigará a México por desapariciones
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3984
#
# Extrayendo: https://letrafria.com/ratifican-comision-de-trabajo-para-restaurar-la-sierra-de-quila/
# ✓ Título: Ratifican comisión de trabajo para restaurar la Sierra de Quila
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2961
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/3/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/perforaran-pozo-profundo-en-zapotlan-el-grande-para-garantizar-abasto-de-agua/
# ✓ Título: Perforarán pozo en Zapotlán El Grande para garantizar abasto de agua
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1435
#
# Extrayendo: https://letrafria.com/periodistas-de-a-pie-senala-uso-indebido-de-su-marca/
# ✓ Título: Periodistas de a Pie señala uso indebido de su marca
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1576
#
# Extrayendo: https://letrafria.com/union-de-tula-recibio-mayor-cantidad-de-remesas-per-capita-en-jalisco/
# ✓ Título: Unión de Tula recibió mayor cantidad de remesas per cápita en Jalisco
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1139
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/4/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/jalisco-menos-vulnerable-a-posibles-aranceles-estadounidenses/
# ✓ Título: Jalisco, menos vulnerable a posibles aranceles estadounidenses
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1856
#
# Extrayendo: https://letrafria.com/el-grullo-inaugura-sala-multisensorial-para-ninez-con-autismo/
# ✓ Título: El Grullo inaugura sala multisensorial para niñez con autismo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 869
#
# Extrayendo: https://letrafria.com/lemus-va-contra-narco-corridos-en-eventos-publicos/
# ✓ Título: Lemus va contra narco corridos en eventos públicos
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1943
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/5/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/entregan-instalaciones-de-la-unidad-municipal-de-proteccion-civil-el-limon/
# ✓ Título: Entregan instalaciones de la Unidad Municipal de Protección Civil El Limón
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1815
#
# Extrayendo: https://letrafria.com/lemus-define-proyectos-para-2025-con-alcaldes-y-alcaldesas/
# ✓ Título: Lemus define proyectos para 2025 con alcaldes y alcaldesas
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2878
#
# Extrayendo: https://letrafria.com/pablo-lemus-inaugura-obras-en-el-grullo-en-su-primera-gira-por-la-region/
# ✓ Título: Pablo Lemus inaugura obras en El Grullo, en su primera gira por la región
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3210
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/29/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/el-grullo-ratifica-hermanamiento-con-downey-california/
# ✓ Título: El Grullo ratifica hermanamiento con Downey, California
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2656
#
# Extrayendo: https://letrafria.com/la-huerta-registra-nutrida-afluencia-de-visitantes-en-fiestas-patronales/
# ✓ Título: La Huerta registra nutrida afluencia de visitantes en fiestas patronales
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2494
#
# Extrayendo: https://letrafria.com/uma-y-sanciones-aumentara-en-febrero/
# ✓ Título: UMA (y sanciones) aumentará en febrero
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1939
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/30/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/comienzan-multas-en-todo-jalisco-por-portaplacas-inadecuadas/
# ✓ Título: Comienzan multas en todo Jalisco por portaplacas “inadecuadas”
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2539
#
# Extrayendo: https://letrafria.com/en-sesion-solemne-formalizan-hermanamiento-entre-ejutla-y-el-limon/
# ✓ Título: En sesión solemne, formalizan hermanamiento entre Ejutla y El Limón
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3159
#
# Extrayendo: https://letrafria.com/que-debes-tener-en-cuenta-en-estos-dias-de-bajas-temperaturas/
# ✓ Título: ¿Qué debes tener en cuenta en estos días de bajas temperaturas?
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3280
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/31/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/en-fin-de-ano-disminuyo-afluencia-de-visitantes-en-la-manzanilla/
# ✓ Título: En fin de año, disminuyó afluencia de visitantes en La Manzanilla
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3690
#
# Extrayendo: https://letrafria.com/uso-pirotecnia-incendios-region-fiestas-decembrinas/
# ✓ Título: Uso de pirotecnia provocó 38 incendios en la región durante fiestas decembrinas
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3834
#
# Extrayendo: https://letrafria.com/bono-navideno-sera-entregado-a-algunos-trabajadores-de-salud/
# ✓ Título: “Bono navideño” se entregará a algunos trabajadores de salud
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2797
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/32/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/sin-danos-tras-sismo-registrado-esta-manana-en-cihuatlan/
# ✓ Título: Sin daños tras sismo registrado esta mañana en Cihuatlán
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 901
#
# Extrayendo: https://letrafria.com/revisaran-inconformidades-de-docentes-de-educacion-fisica/
# ✓ Título: Revisarán inconformidades de docentes de educación física
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1401
#
# Extrayendo: https://letrafria.com/nombran-a-socorro-preciado-como-titular-de-la-drse-sierra-de-amula/
# ✓ Título: Nombran a Socorro Preciado como titular de la DRSE Sierra de Amula
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2567
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/33/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/tecolotlenses-hacen-peticiones-para-el-proximo-carnaval-2025/
# ✓ Título: Tecolotlenses hacen peticiones para el próximo Carnaval 2025
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2089
#
# Extrayendo: https://letrafria.com/habra-fondo-para-pueblos-magicos-tapalpa-sera-beneficiado/
# ✓ Título: Habrá fondo para Pueblos Mágicos; Tapalpa será beneficiado
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2230
#
# Extrayendo: https://letrafria.com/conceden-apelacion-al-ejido-emiliano-zapata-pero-particular-se-resiste/
# ✓ Título: Conceden apelación al Ejido Emiliano Zapata, pero particular se resiste
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4758
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ...
#
# Extrayendo: https://letrafria.com/autlan-confirma-ocho-fallecidos-y-seis-desaparecidos-por-desborde-de-el-cangrejo/
# ✓ Título: Autlán confirma ocho fallecidos y seis desaparecidos por desborde de El Cangrejo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1466
#
# Extrayendo: https://letrafria.com/ballet-dulce-cana-de-lo-arado-para-todo-mexico/
# ✓ Título: Ballet Dulce Caña: de Lo Arado para todo México
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 5447
#
# Extrayendo: https://letrafria.com/destinaran-10-mdp-para-remodelar-camino-de-tecolotlan-a-quila/
# ✓ Título: Destinarán 10 mdp para remodelar el camino de Tecolotlán a Quila
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1639
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/191/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/fernando-gomez-carrasco-pide-recursos-al-gobierno-de-jalisco/
# ✓ Título: Fernando Gómez Carrasco pide más apoyo y recursos al gobierno de Jalisco
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1831
#
# Extrayendo: https://letrafria.com/aprueban-predios-para-banco-de-bienestar-en-la-costa-sur/
# ✓ Título: Aprueban predios para Banco de Bienestar en la Costa Sur
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1098
#
# Extrayendo: https://letrafria.com/autlan-de-los-municipios-que-mas-empleos-perdio-en-agosto/
# ✓ Título: Autlán, de los municipios que más empleos perdió en agosto
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1449
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/192/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/ejutla-cuenta-con-su-propio-centro-integrador-de-programas-del-bienestar/
# ✓ Título: Ejutla cuenta con su propio Centro Integrador de Programas del Bienestar
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2430
#
# Extrayendo: https://letrafria.com/obras-en-escuelas-de-la-region-presentan-retraso/
# ✓ Título: Obras en escuelas de la región presentan retraso
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2286
#
# Extrayendo: https://letrafria.com/ssj-busca-atender-menores-diabetes-estado/
# ✓ Título: SSJ busca atender a menores con diabetes tipo 1 de todo el estado
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3946
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/193/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/mecanismo-de-proteccion-de-segob-deja-en-desamparo-a-periodista-desplazada/
# ✓ Título: Mecanismo de Protección de SEGOB deja en desamparo a periodista desplazada
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 12426
#
# Extrayendo: https://letrafria.com/abren-campana-de-deteccion-de-osteoporosis-en-union-de-tvla/
# ✓ Título: Abren campaña de detección de osteoporosis en Unión de Tvla
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1375
#
# Extrayendo: https://letrafria.com/certifican-predio-en-cabo-corrientes-como-area-estatal-destinada-voluntariamente-a-la-conservacion/
# ✓ Título: Certifican predio en Cabo Corrientes como Área Estatal Destinada Voluntariamente a la Conservación
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3042
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/194/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/gala-lepe-formo-parte-la-cumbre-internacional-de-habitat/
# ✓ Título: Gala Lepe participó en la Cumbre Internacional del Hábitat
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1486
#
# Extrayendo: https://letrafria.com/descuento-del-mes-del-testamento-se-extendera-hasta-octubre/
# ✓ Título: Descuento del “Mes del Testamento” se extenderá hasta octubre
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2251
#
# Extrayendo: https://letrafria.com/los-nuevos-libros-de-texto-adoctrinan/
# ✓ Título: Los nuevos libros de texto, ¿’adoctrinan’?
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2935
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/195/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/hoy-comenzaran-a-repartir-libros-de-texto-gratuitos-en-jalisco/
# ✓ Título: Hoy comenzarán a repartir libros de texto gratuitos en Jalisco
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2117
#
# Extrayendo: https://letrafria.com/ciclo-escolar-2023-2024-inician-clases-sin-profesores/
# ✓ Título: Ciclo escolar 2023-2024: la región inicia clases sin profesores
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2287
#
# Extrayendo: https://letrafria.com/una-escuela-campesina-en-casimiro-castillo/
# ✓ Título: Una escuela campesina en Casimiro Castillo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3647
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/196/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/abren-la-primera-carniceria-libre-de-deforestacion-en-la-costa-sur/
# ✓ Título: Abren la primera carnicería libre de deforestación en la Costa Sur
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2853
#
# Extrayendo: https://letrafria.com/personas-de-la-region-podran-crear-proyectos-audiovisuales-de-su-territorio/
# ✓ Título: Personas de la región podrán crear proyectos audiovisuales de su territorio
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2346
#
# Extrayendo: https://letrafria.com/entregaran-computadoras-a-docentes-de-primaria/
# ✓ Título: Entregarán computadoras a docentes de primaria en Jalisco
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1739
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/197/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/conoces-el-origen-de-tus-alimentos/
# ✓ Título: ¿Conoces el origen de tus alimentos?
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 5273
#
# Extrayendo: https://letrafria.com/corrupcion-en-jalisco-sin-castigo/
# ✓ Título: Corrupción en Jalisco, sin castigo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3420
#
# Extrayendo: https://letrafria.com/red-macollo-respalda-a-la-periodista-celia-espinoza-en-lagos-de-moreno/
# ✓ Título: Red Macollo respalda a la periodista Celia Espinoza en Lagos de Moreno
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1765
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/198/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/quila-exige-aclaraciones-y-compromisos-por-parte-de-empresas-agroindustriales/
# ✓ Título: Quila exige aclaraciones y compromisos por parte de empresas agroindustriales
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4603
#
# Extrayendo: https://letrafria.com/romeria-2023-tenamaxtlan-y-atengo-se-unen-en-operativo-especial-de-seguridad/
# ✓ Título: Romería 2023: Tenamaxtlán y Atengo se unen en operativo especial de seguridad
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2148
#
# Extrayendo: https://letrafria.com/suspenden-bloqueos-en-quila-comunidad-entabla-dialogo-con-empresas/
# ✓ Título: Suspenden bloqueos en Quila; comunidad entabla diálogo con empresas
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1479
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/199/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/por-dia-de-las-paseadoras-union-de-tvla-refuerza-seguridad/
# ✓ Título: Por Día de las Paseadoras Unión de Tvla refuerza seguridad
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2546
#
# Extrayendo: https://letrafria.com/hay-menos-pobres-en-jalisco-coneval/
# ✓ Título: Hay menos pobres en Jalisco: Coneval
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2698
#
# Extrayendo: https://letrafria.com/itei-impone-amonestaciones-otra-vez-a-funcionaria-de-tomatlan/
# ✓ Título: Itei impone amonestaciones, otra vez, a funcionaria de Tomatlán
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1649
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Obteniendo artículos de: https://letrafria.com/category/region/page/200/
# Encontrados 7 artículos
#
# Extrayendo: https://letrafria.com/romeria-2023-la-virgen-peregrina-regresa-a-atengo/
# ✓ Título: Romería 2023: La virgen peregrina regresa a Atengo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 3104
#
# Extrayendo: https://letrafria.com/todo-listo-para-celebrar-el-dia-de-las-paseadoras-2023/
# ✓ Título: Todo listo para celebrar el Día de las Paseadoras 2023
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2819
#
# Extrayendo: https://letrafria.com/union-de-tvla-alista-todo-para-vivir-el-festival-del-ponche-2023/
# ✓ Título: Unión de Tvla alista todo para vivir el Festival del Ponche 2023
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1860
#
# Extrayendo: https://letrafria.com/prohiben-acceso-de-vehiculos-a-playas-de-melaque/
# ✓ Título: Prohíben acceso de vehículos a playas de Melaque
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1075
#
# Extrayendo: https://letrafria.com/abriran-modulo-permanente-de-licencias-de-conducir-en-el-grullo/
# ✓ Título: Abrirán módulo permanente de licencias de conducir en El Grullo
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 1031
#
# Extrayendo: https://letrafria.com/encuentro-jovenes-y-agroecologia-en-el-limon-supera-los-600-asistentes/
# ✓ Título: Encuentro Jóvenes y Agroecología en El Limón supera los 600 asistentes
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 2406
#
# Extrayendo: https://letrafria.com/sandra-borja/
# ✓ Título: Sandra Borja
# ✓ Fecha:
# ✓ Autor:
# ✓ Caracteres: 4252
#
# Prueba completada. Artículos extraídos: 1398
# Archivo guardado: letra_fria_200_20250414_120843.csv
#
# Tiempo total: 130m 46s
